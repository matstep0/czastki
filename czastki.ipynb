# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Wenu.csv")
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 16 columns):
# Run            100000 non-null int64
# Event          100000 non-null int64
# pt             100000 non-null float64
# eta            100000 non-null float64
# phi            100000 non-null float64
# Q              100000 non-null int64
# type           100000 non-null object
# delEta         100000 non-null int64
# delPhi         100000 non-null int64
# sigmaEtaEta    100000 non-null float64
# HoverE         100000 non-null float64
# isoTrack       100000 non-null float64
# isoEcal        100000 non-null float64
# isoHcal        100000 non-null float64
# MET            100000 non-null float64
# phiMET         100000 non-null float64
# dtypes: float64(10), int64(5), object(1)
# memory usage: 12.2+ MB
# None
#       Run      Event       pt     eta     phi  Q type  delEta  delPhi  \
# 0  167676  328843401  38.6387 -0.8499  1.8486 -1   EB       0       0
# 1  167676  328836311  59.1666 -2.1095 -2.5163  1   EE       0       0
# 2  167676  328915343  31.7262  2.4504  2.8956  1   EE       0       0
# 3  167676  328884653  73.4109 -1.3951  2.0052 -1   EB       0       0
# 4  167676  328970109  49.1363 -2.4326  3.0219  1   EE       0       0
#
#    sigmaEtaEta  HoverE  isoTrack  isoEcal  isoHcal      MET  phiMET
# 0       0.0095  0.0000    0.0000   1.2241   0.0000  46.7884 -1.3886
# 1       0.0214  0.0177   20.4771   2.5441   6.7450  15.0179  1.1503
# 2       0.0288  0.0000    0.7775   1.8222   0.3663  20.6550 -0.2703
# 3       0.0100  0.0000   22.8584   8.0151   8.2951   3.2858 -0.7739
# 4       0.0271  0.0000    0.0000   0.1154   0.0000   3.1425  2.5081

# %%
typeQ=df.loc[:,["Q","type"] ]

# %%
EB1=len(typeQ.loc[(typeQ.Q==1) & (typeQ.type=="EB")])
EBm1=len(typeQ.loc[(typeQ.Q==-1) & (typeQ.type=="EB")])
EE1=len(typeQ.loc[(typeQ.Q==1) & (typeQ.type=="EE")])
EEm1=len(typeQ.loc[(typeQ.Q==-1) & (typeQ.type=="EE")])
data={-1: [EBm1,EEm1] ,1: [EB1,EE1] }
pd.DataFrame(data,index=["EB","EE"])
# Out:
#        -1      1
# EB  25475  28606
# EE  21694  24225

# %%
runy=typeQ=df.loc[:,["Q","type","Run"] ]

# %%
def fun(typeQ):
    EB1=len(typeQ.loc[(typeQ.Q==1) & (typeQ.type=="EB")])
    EBm1=len(typeQ.loc[(typeQ.Q==-1) & (typeQ.type=="EB")])
    EE1=len(typeQ.loc[(typeQ.Q==1) & (typeQ.type=="EE")])
    EEm1=len(typeQ.loc[(typeQ.Q==-1) & (typeQ.type=="EE")])
    return [EEm1,EBm1,EE1,EB1, EB1+EBm1+EE1+EEm1]

# %%
groped=runy.groupby("Run").apply(fun)
groped
# Out:
# Run
# 161312      [959, 1217, 1076, 1414, 4666]
# 163376         [542, 540, 657, 611, 2350]
# 163402         [342, 373, 373, 368, 1456]
# 163659         [505, 571, 549, 616, 2241]
# 163758         [299, 370, 390, 361, 1420]
# 163759    [3501, 3854, 3832, 4321, 15508]
# 163817        [879, 960, 916, 1037, 3792]
# 165121         [531, 468, 552, 493, 2044]
# 165415          [137, 114, 162, 174, 587]
# 165467     [1138, 1037, 1210, 1163, 4548]
# 165514         [532, 534, 610, 575, 2251]
# 165537         [475, 400, 449, 452, 1776]
# 165567    [3064, 2776, 3229, 3248, 12317]
# 165633         [529, 520, 586, 584, 2219]
# 166034         [471, 512, 558, 526, 2067]
# 166049     [1289, 1337, 1392, 1490, 5508]
# 166408         [547, 623, 600, 650, 2420]
# 166512          [212, 241, 203, 247, 903]
# 166514         [545, 598, 660, 595, 2398]
# 166565         [542, 652, 653, 699, 2546]
# 166782         [518, 557, 562, 616, 2253]
# 167676         [480, 664, 500, 760, 2404]
# 170876       [763, 1158, 894, 1337, 4152]
# 171446     [1183, 2111, 1497, 2482, 7273]
# 171484         [395, 714, 466, 841, 2416]
# 172822         [244, 488, 307, 561, 1600]
# 172868       [730, 1384, 922, 1609, 4645]
# 172949         [342, 702, 420, 776, 2240]
# dtype: object

# %%
print(df.columns)
# Out:
# Index(['Run', 'Event', 'pt', 'eta', 'phi', 'Q', 'type', 'delEta', 'delPhi',
#        'sigmaEtaEta', 'HoverE', 'isoTrack', 'isoEcal', 'isoHcal', 'MET',
#        'phiMET'],
#       dtype='object')

# %%
zakres=['pt', 'eta', 'phi', 'Q', 'MET',
       'phiMET' ]

# %%
typeEB=df.loc[(df.type=="EB")]
typeEE=df.loc[(df.type=="EE")]

# %%
i=0
name=zakres[i]
plt=typeEB[name].plot(kind="hist",bins=50,range=[20,120])
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EB/EB_'+name+'.pdf')

# %%
i=1
name=zakres[i]
plt=typeEB[name].plot(kind="hist",bins=50)
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EB/EB_'+name+'.pdf')

# %%
i=2
name=zakres[i]
plt=typeEB[name].plot(kind="hist",bins=50)
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EB/EB_'+name+'.pdf')

# %%
i=3
name=zakres[i]
plt=typeEB[name].plot(kind="hist",bins=50)
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EB/EB_'+name+'.pdf')

# %%
i=4
name=zakres[i]
plt=typeEB[name].plot(kind="hist",bins=50,range=[0,150])
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EB/EB_'+name+'.pdf')

# %%
i=5
name=zakres[i]
plt=typeEB[name].plot(kind="hist",bins=50)
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EB/EB_'+name+'.pdf')

# %%
i=0
name=zakres[i]
plt=typeEE[name].plot(kind="hist",bins=50,range=[20,120])
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EE/EE_'+name+'.pdf')

# %%
i=1
name=zakres[i]
plt=typeEE[name].plot(kind="hist",bins=50)
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EE/EE_'+name+'.pdf')

# %%
i=2
name=zakres[i]
plt=typeEE[name].plot(kind="hist",bins=50)
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EE/EE_'+name+'.pdf')

# %%
i=3
name=zakres[i]
plt=typeEE[name].plot(kind="hist",bins=50)
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EE/EE_'+name+'.pdf')

# %%
i=4
name=zakres[i]
plt=typeEE[name].plot(kind="hist",bins=50,range=[0,150])
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EE/EE_'+name+'.pdf')

# %%
i=5
name=zakres[i]
plt=typeEE[name].plot(kind="hist",bins=50)
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EE/EE_'+name+'.pdf')

# %%
i=0
name=zakres[i]
plt=df[name].plot(kind="hist",bins=50,range=[20,120])
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EBEE/_'+name+'.pdf')

# %%
i=1
name=zakres[i]
plt=df[name].plot(kind="hist",bins=50)
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EBEE/_'+name+'.pdf')

# %%
i=2
name=zakres[i]
plt=df[name].plot(kind="hist",bins=50)
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EBEE/_'+name+'.pdf')

# %%
i=3
name=zakres[i]
plt=df[name].plot(kind="hist",bins=50)
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EBEE/_'+name+'.pdf')

# %%
i=4
name=zakres[i]
plt=df[name].plot(kind="hist",bins=50,range=[0,150])
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EBEE/_'+name+'.pdf')

# %%
i=5
name=zakres[i]
plt=df[name].plot(kind="hist",bins=50)
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('EBEE/_'+name+'.pdf')

# %%
data=df.loc[df.pt>25]

# %%
i=0
name=zakres[i]
plt=data[name].plot(kind="hist",bins=50,range=[20,120])
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('ciete25/_'+name+'.pdf')

# %%
i=1
name=zakres[i]
plt=df[name].plot(kind="hist",bins=50)
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('ciete25/_'+name+'.pdf')

# %%
i=4
name=zakres[i]
plt=df[name].plot(kind="hist",bins=50)
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
fig = plt.get_figure()
fig.savefig('ciete25/_'+name+'.pdf')

# %%
i=5
name=zakres[i]
plt=df[name].plot(kind="hist",bins=50)
plt.set_xlabel(name)
plt.set_ylabel("Number of events")
>fig = plt.get_figure()
fig.savefig('ciete25/_'+name+'.pdf')
